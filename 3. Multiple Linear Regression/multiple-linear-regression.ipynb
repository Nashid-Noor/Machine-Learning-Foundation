# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import pandas as pd 
import numpy as np 

import plotly.express as px
import plotly.graph_objects as go

# %%
X,Y= make_regression(n_features=2,n_samples=100,n_informative=2,n_targets=1,noise=50)

# %%
df=pd.DataFrame({'feature 1': X[:,0],'feature 2': X[:,1],'target':Y})
df.head()
# Out:
#    feature 1  feature 2      target
# 0   0.537937  -0.626028  -16.244080
# 1   0.380035   1.362413  278.307177
# 2  -0.457385   0.027508 -179.321783
# 3  -0.344930   1.051206   37.125854
# 4  -0.585381   0.407015  -83.505482

# %%
fig= px.scatter_3d(df,x='feature 1',y='feature 2',z='target')
fig.show()

# %%
X_train,X_test,Y_train,Y_test= train_test_split(X,Y, test_size=0.2,random_state=2)
lr= LinearRegression()
lr.fit(X_train,Y_train)
lr.predict()
