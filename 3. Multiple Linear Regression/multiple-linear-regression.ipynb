# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import pandas as pd 
import numpy as np 

import plotly.express as px
import plotly.graph_objects as go

# %%
X,Y= make_regression(n_features=2,n_samples=100,n_informative=2,n_targets=1,noise=50)

# %%
df=pd.DataFrame({'feature 1': X[:,0],'feature 2': X[:,1],'target':Y})
df.head()
# Out:
#    feature 1  feature 2      target
# 0   0.768416   0.358242   67.550558
# 1  -1.245919  -0.598807 -155.283568
# 2  -2.113026   0.605365 -141.487231
# 3  -0.313008  -0.115605   -0.680368
# 4   0.712745   0.464465   77.239190

# %%
fig= px.scatter_3d(df,x='feature 1',y='feature 2',z='target')
fig.show()

# %%
X_train,X_test,Y_train,Y_test= train_test_split(X,Y, test_size=0.2,random_state=2)
lr= LinearRegression()
lr.fit(X_train,Y_train)
lr.predict(X_test)
# Out:
# array([  43.80783245,  -84.46054023,  -22.26095249,   90.23964026,
#          64.8753451 ,  -37.3756865 ,  -57.06933352,    3.63621908,
#          56.957006  ,  -37.17569879, -123.5518017 ,   57.06216585,
#         162.09102593,  -30.91285582,   72.95380742, -109.93017848,
#         -22.73196788,   -2.92953175,   31.95422056, -111.3921214 ])
