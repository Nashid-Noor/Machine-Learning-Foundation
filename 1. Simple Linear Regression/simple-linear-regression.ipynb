# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("placement.csv")
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df["cgpa"],df["package"])
plt.xlabel("CGPA")
plt.ylabel("Package")
plt.show()

# %%
X=df.iloc[:,:1]
Y=df.iloc[:,-1]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
lr = LinearRegression()
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
#lr.predict(X_test.iloc[0].values.reshape(1,1))
#X_test.iloc[0].values.reshape(1,1)
lr.predict(X_test.iloc[[0]].values)
# Out:
# /Users/noormohammed/.pyenv/versions/3.11.0/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.97012606])

# %%
X_test=X_test.iloc[[0]]
Y_test=Y_test.iloc[[0]]
print(X_test)
print(Y_test)
# Out:
#     cgpa
# 18  6.94
# 18    2.98
# Name: package, dtype: float64

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
m=lr.coef_
b=lr.intercept_
print(m,b)
# Out:
# [0.57633042] -1.0296070415163112

# %%
# y= m*x+b
y=m * X_test.iloc[0].item() + b
y
# Out:
# array([2.97012606])
